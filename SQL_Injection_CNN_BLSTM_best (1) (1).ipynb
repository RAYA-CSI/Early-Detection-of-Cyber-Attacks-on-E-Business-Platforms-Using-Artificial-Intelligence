# %%
import numpy as np
import os
import kagglehub
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, LSTM, Bidirectional, Dense, Dropout, Flatten, SpatialDropout1D, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall
import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
import shutil

# %%
path = kagglehub.dataset_download("ayahkhaldi/sql-injection-dataset")
print("Path to dataset files:", path)

new_folder = '/content/sample_data/'
os.makedirs(new_folder, exist_ok=True)

datafiles = os.listdir(path)
for f in datafiles:
    src_path = os.path.join(path, f)
    dst_path = os.path.join(new_folder, f)

    if os.path.isdir(src_path):
        shutil.copytree(src_path, dst_path)
    else:
        shutil.copy2(src_path, dst_path)
# Out:
# Path to dataset files: /kaggle/input/sql-injection-dataset

# %%
path = kagglehub.dataset_download("rtatman/glove-global-vectors-for-word-representation")
print("Path to dataset files:", path)

new_folder = '/content/sample_data/'
os.makedirs(new_folder, exist_ok=True)

datafiles = os.listdir(path)
for f in datafiles:
    src_path = os.path.join(path, f)
    dst_path = os.path.join(new_folder, f)

    if os.path.isdir(src_path):
        shutil.copytree(src_path, dst_path)
    else:
        shutil.copy2(src_path, dst_path)
# Out:
# Path to dataset files: /kaggle/input/glove-global-vectors-for-word-representation

# %%
train_data_frame = pd.read_csv("/content/sample_data/sql-injection-datasets/Train.csv" ,lineterminator='\n')

# %%
train_data_frame.head()
# Out:
#                                                Query  Label
# 0  The film 'Nightbreed' is one of the best horro...      0
# 1  The story for Hare Rama Hare Krishna actually ...      0
# 2  1" where 6347 = 6347 union all select null,nul...      1
# 3  jk dv1z0r39am1wjiiumia9xrxdowuo87f 110dcc d0ej...      1
# 4  1'||  (  select 'fdkl' where 4572  =  4572 uni...      1

# %%
test_data_frame = pd.read_csv("/content/sample_data/sql-injection-datasets/Test.csv")

# %%
test_data_frame.head()
# Out:
#                                                Query  Label
# 0  A pretentious but - to varying degrees - watch...    0.0
# 1   Tamar-Mattis said organization supports Austr...    0.0
# 2                                               5337    0.0
# 3  SELECT * FROM nothing WHERE quick NOT LIKE '[s...    0.0
# 4  SELECT TOP 50 PERCENT * FROM according SELECT ...    0.0

# %%
validation_data_frame = pd.read_csv("/content/sample_data/sql-injection-datasets/Validation.csv")

# %%
validation_data_frame.head()
# Out:
#                                                Query  Label
# 0  Genius or utter madness? That depends on your ...    0.0
# 1  Most who go to this movie will have an idea wh...    0.0
# 2                   SELECT safe ( s )  FROM stranger    0.0
# 3    SELECT Orders.knownrID, Employees.whale, Emp...    0.0
# 4  9999999999999999999999999999999999999999999999...    1.0

# %%
print("file 1 = ",len(train_data_frame))
print("file 2 = ",len(test_data_frame))
print("file 3 = ",len(validation_data_frame))
# Out:
# file 1 =  98062
# file 2 =  32696
# file 3 =  32695

# %%
train_data_frame.isna().sum()
# Out:
# Query    0
# Label    0
# dtype: int64

# %%
train_data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98062 entries, 0 to 98061
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Query   98062 non-null  object
#  1   Label   98062 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
test_data_frame.isna().sum()
# Out:
# Query    0
# Label    8
# dtype: int64

# %%
test_data_frame = test_data_frame.dropna()

# %%
test_data_frame.isna().sum()
# Out:
# Query    0
# Label    0
# dtype: int64

# %%
test_data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32688 entries, 0 to 32695
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Query   32688 non-null  object
#  1   Label   32688 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 766.1+ KB

# %%
validation_data_frame.isna().sum()
# Out:
# Query    0
# Label    8
# dtype: int64

# %%
validation_data_frame = validation_data_frame.dropna()

# %%
validation_data_frame.isna().sum()
# Out:
# Query    0
# Label    0
# dtype: int64

# %%
validation_data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32687 entries, 0 to 32694
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Query   32687 non-null  object
#  1   Label   32687 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 766.1+ KB

# %%
train_data_frame[train_data_frame['Label'] == 1].count()
# Out:
# Query    46685
# Label    46685
# dtype: int64

# %%
train_data_frame[train_data_frame['Label'] == 0].count()
# Out:
# Query    51377
# Label    51377
# dtype: int64

# %%
test_data_frame[test_data_frame['Label'] == 1].count()
# Out:
# Query    15494
# Label    15494
# dtype: int64

# %%
test_data_frame[test_data_frame['Label'] == 0].count()
# Out:
# Query    17194
# Label    17194
# dtype: int64

# %%
labels = ['0', '1']
colors = ['#3242a8', '#a83242']
explode = (0.1, 0)

# %%
sizes = train_data_frame['Label'].value_counts()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, explode=explode, shadow=True)
plt.title('File ')
plt.show()

# %%
sizes = test_data_frame['Label'].value_counts()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, explode=explode, shadow=True)
plt.title('File ')
plt.show()

# %%
data_frame = pd.concat([train_data_frame, test_data_frame], ignore_index=True)

# %%
data_frame.head()
# Out:
#                                                Query  Label
# 0  The film 'Nightbreed' is one of the best horro...    0.0
# 1  The story for Hare Rama Hare Krishna actually ...    0.0
# 2  1" where 6347 = 6347 union all select null,nul...    1.0
# 3  jk dv1z0r39am1wjiiumia9xrxdowuo87f 110dcc d0ej...    1.0
# 4  1'||  (  select 'fdkl' where 4572  =  4572 uni...    1.0

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130750 entries, 0 to 130749
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Query   130750 non-null  object
#  1   Label   130750 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.0+ MB

# %%
max_words = 100
max_len = 100
embedding_dim = 100
tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")

# %%
train_query = train_data_frame['Query']
train_label = train_data_frame['Label']

test_query = test_data_frame['Query']
test_label = test_data_frame['Label']

validation_query = validation_data_frame['Query']
validation_label = validation_data_frame['Label']

# %%
print(type(train_query))
print(type(train_query[0]))
print(train_query[0])
# Out:
# <class 'pandas.core.series.Series'>
# <class 'str'>
# The film 'Nightbreed' is one of the best horror films I have ever seen. Overall, I'm not a big fan of horror films, but there is something about this film that is more atmospheric and different from any other horror film I have ever seen. Many horror films i've seen i've en

# %%
train_query_lower = []
for text in train_query :
  train_query_lower.append(text.lower())

tokenizer.fit_on_texts(train_query_lower)
sequences = tokenizer.texts_to_sequences(train_query_lower)
X = pad_sequences(sequences, maxlen=max_len)

# %%
test_query_lower = []
for text in test_query :
  test_query_lower.append(text.lower())

tokenizer.fit_on_texts(test_query_lower)
sequences = tokenizer.texts_to_sequences(test_query_lower)
x_test = pad_sequences(sequences, maxlen=max_len)

# %%
validation_query_lower = []
for text in validation_query :
  validation_query_lower.append(text.lower())

tokenizer.fit_on_texts(validation_query_lower)
sequences = tokenizer.texts_to_sequences(validation_query_lower)
X_validation = pad_sequences(sequences, maxlen=max_len)

# %%
Y = np.array(train_label)
y_test = np.array(test_label)
y_validation = np.array(validation_label)

# %%
embedding_index = {}
with open("/content/sample_data/glove.6B.100d.txt", encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype="float32")
        embedding_index[word] = coefs

# %%
word_index = tokenizer.word_index
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    if i < max_words and word in embedding_index:
        embedding_matrix[i] = embedding_index[word]

# %%
epochs = 30
batch_size = 256

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, weights=[embedding_matrix], input_length=max_len, trainable=True),
    SpatialDropout1D(0.2),
    Conv1D(filters=256, kernel_size=5, activation='relu'),
    BatchNormalization(),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    Bidirectional(LSTM(128, return_sequences=True)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.build(input_shape=(batch_size, max_words))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
              loss='binary_crossentropy',
              metrics=[
        'accuracy',
        Precision(name='precision'),
        Recall(name='recall'),
    ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (256, 100, 100)        │        10,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d               │ (256, 100, 100)        │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (256, 96, 256)         │       128,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (256, 96, 256)         │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (256, 92, 128)         │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (256, 46, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (256, 46, 256)         │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (256, 11776)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (256, 128)             │     1,507,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (256, 128)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (256, 1)               │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,074,001 (7.91 MB)
#  Trainable params: 2,073,489 (7.91 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
checkpoint_path = "best_model.h5"
model_checkpoint = ModelCheckpoint(filepath=checkpoint_path,
    monitor='val_accuracy',save_best_only=True,
    mode='max',verbose=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (88255, 100)
# (9807, 100)
# (88255,)
# (9807,)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(Y_train), y=Y_train.flatten())
class_weights = dict(enumerate(class_weights))

# %%
history = model.fit(
    X_train, Y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_test, Y_test),
    class_weight=class_weights,
    callbacks=[model_checkpoint],
    verbose=1
)
# Out:
# Epoch 1/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8766 - loss: 0.2816 - precision: 0.8909 - recall: 0.8478
# Epoch 1: val_accuracy improved from -inf to 0.97023, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 23s 40ms/step - accuracy: 0.8768 - loss: 0.2813 - precision: 0.8911 - recall: 0.8480 - val_accuracy: 0.9702 - val_loss: 0.0998 - val_precision: 0.9933 - val_recall: 0.9441
# Epoch 2/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9711 - loss: 0.1024 - precision: 0.9864 - recall: 0.9527
# Epoch 2: val_accuracy improved from 0.97023 to 0.97553, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9712 - loss: 0.1024 - precision: 0.9864 - recall: 0.9527 - val_accuracy: 0.9755 - val_loss: 0.0849 - val_precision: 0.9912 - val_recall: 0.9573
# Epoch 3/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9745 - loss: 0.0884 - precision: 0.9889 - recall: 0.9569
# Epoch 3: val_accuracy improved from 0.97553 to 0.97573, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9745 - loss: 0.0884 - precision: 0.9889 - recall: 0.9569 - val_accuracy: 0.9757 - val_loss: 0.0856 - val_precision: 0.9947 - val_recall: 0.9543
# Epoch 4/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9762 - loss: 0.0837 - precision: 0.9915 - recall: 0.9582
# Epoch 4: val_accuracy improved from 0.97573 to 0.97685, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9762 - loss: 0.0837 - precision: 0.9915 - recall: 0.9582 - val_accuracy: 0.9769 - val_loss: 0.0818 - val_precision: 0.9916 - val_recall: 0.9596
# Epoch 5/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9775 - loss: 0.0777 - precision: 0.9922 - recall: 0.9601
# Epoch 5: val_accuracy did not improve from 0.97685
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9775 - loss: 0.0777 - precision: 0.9922 - recall: 0.9601 - val_accuracy: 0.9759 - val_loss: 0.0829 - val_precision: 0.9914 - val_recall: 0.9579
# Epoch 6/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9797 - loss: 0.0699 - precision: 0.9935 - recall: 0.9634
# Epoch 6: val_accuracy improved from 0.97685 to 0.97859, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9797 - loss: 0.0699 - precision: 0.9935 - recall: 0.9634 - val_accuracy: 0.9786 - val_loss: 0.0807 - val_precision: 0.9943 - val_recall: 0.9607
# Epoch 7/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9796 - loss: 0.0673 - precision: 0.9933 - recall: 0.9636
# Epoch 7: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9796 - loss: 0.0673 - precision: 0.9933 - recall: 0.9636 - val_accuracy: 0.9786 - val_loss: 0.0827 - val_precision: 0.9914 - val_recall: 0.9635
# Epoch 8/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9805 - loss: 0.0626 - precision: 0.9940 - recall: 0.9652
# Epoch 8: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9805 - loss: 0.0626 - precision: 0.9940 - recall: 0.9652 - val_accuracy: 0.9776 - val_loss: 0.0861 - val_precision: 0.9897 - val_recall: 0.9631
# Epoch 9/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9826 - loss: 0.0558 - precision: 0.9937 - recall: 0.9696
# Epoch 9: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9826 - loss: 0.0558 - precision: 0.9937 - recall: 0.9696 - val_accuracy: 0.9776 - val_loss: 0.0926 - val_precision: 0.9927 - val_recall: 0.9601
# Epoch 10/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9844 - loss: 0.0505 - precision: 0.9936 - recall: 0.9735
# Epoch 10: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9844 - loss: 0.0505 - precision: 0.9936 - recall: 0.9735 - val_accuracy: 0.9766 - val_loss: 0.0944 - val_precision: 0.9880 - val_recall: 0.9629
# Epoch 11/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9852 - loss: 0.0466 - precision: 0.9935 - recall: 0.9754
# Epoch 11: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9852 - loss: 0.0466 - precision: 0.9935 - recall: 0.9754 - val_accuracy: 0.9748 - val_loss: 0.1034 - val_precision: 0.9834 - val_recall: 0.9635
# Epoch 12/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9887 - loss: 0.0383 - precision: 0.9941 - recall: 0.9820
# Epoch 12: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9887 - loss: 0.0383 - precision: 0.9941 - recall: 0.9820 - val_accuracy: 0.9757 - val_loss: 0.1140 - val_precision: 0.9849 - val_recall: 0.9639
# Epoch 13/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9899 - loss: 0.0354 - precision: 0.9951 - recall: 0.9837
# Epoch 13: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9899 - loss: 0.0354 - precision: 0.9951 - recall: 0.9837 - val_accuracy: 0.9747 - val_loss: 0.1221 - val_precision: 0.9839 - val_recall: 0.9629
# Epoch 14/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9908 - loss: 0.0336 - precision: 0.9956 - recall: 0.9851
# Epoch 14: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9908 - loss: 0.0336 - precision: 0.9956 - recall: 0.9851 - val_accuracy: 0.9748 - val_loss: 0.1251 - val_precision: 0.9853 - val_recall: 0.9616
# Epoch 15/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9919 - loss: 0.0313 - precision: 0.9963 - recall: 0.9866
# Epoch 15: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9919 - loss: 0.0313 - precision: 0.9963 - recall: 0.9866 - val_accuracy: 0.9771 - val_loss: 0.1365 - val_precision: 0.9890 - val_recall: 0.9626
# Epoch 16/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9925 - loss: 0.0287 - precision: 0.9967 - recall: 0.9875
# Epoch 16: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9925 - loss: 0.0288 - precision: 0.9967 - recall: 0.9875 - val_accuracy: 0.9734 - val_loss: 0.1346 - val_precision: 0.9804 - val_recall: 0.9635
# Epoch 17/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9926 - loss: 0.0276 - precision: 0.9964 - recall: 0.9880
# Epoch 17: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9926 - loss: 0.0276 - precision: 0.9964 - recall: 0.9880 - val_accuracy: 0.9751 - val_loss: 0.1503 - val_precision: 0.9849 - val_recall: 0.9626
# Epoch 18/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9926 - loss: 0.0277 - precision: 0.9967 - recall: 0.9877
# Epoch 18: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9926 - loss: 0.0277 - precision: 0.9967 - recall: 0.9877 - val_accuracy: 0.9762 - val_loss: 0.1514 - val_precision: 0.9867 - val_recall: 0.9633
# Epoch 19/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9930 - loss: 0.0260 - precision: 0.9968 - recall: 0.9886
# Epoch 19: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9930 - loss: 0.0260 - precision: 0.9968 - recall: 0.9886 - val_accuracy: 0.9755 - val_loss: 0.1530 - val_precision: 0.9856 - val_recall: 0.9629
# Epoch 20/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9931 - loss: 0.0260 - precision: 0.9967 - recall: 0.9888
# Epoch 20: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9931 - loss: 0.0260 - precision: 0.9967 - recall: 0.9888 - val_accuracy: 0.9744 - val_loss: 0.1553 - val_precision: 0.9830 - val_recall: 0.9631
# Epoch 21/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9938 - loss: 0.0248 - precision: 0.9977 - recall: 0.9893
# Epoch 21: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9938 - loss: 0.0248 - precision: 0.9977 - recall: 0.9893 - val_accuracy: 0.9751 - val_loss: 0.1559 - val_precision: 0.9839 - val_recall: 0.9637
# Epoch 22/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9931 - loss: 0.0258 - precision: 0.9972 - recall: 0.9884
# Epoch 22: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9931 - loss: 0.0258 - precision: 0.9972 - recall: 0.9884 - val_accuracy: 0.9772 - val_loss: 0.1696 - val_precision: 0.9888 - val_recall: 0.9631
# Epoch 23/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9934 - loss: 0.0250 - precision: 0.9973 - recall: 0.9888
# Epoch 23: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9934 - loss: 0.0250 - precision: 0.9973 - recall: 0.9888 - val_accuracy: 0.9751 - val_loss: 0.1626 - val_precision: 0.9854 - val_recall: 0.9622
# Epoch 24/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9934 - loss: 0.0250 - precision: 0.9974 - recall: 0.9888
# Epoch 24: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9934 - loss: 0.0250 - precision: 0.9974 - recall: 0.9888 - val_accuracy: 0.9756 - val_loss: 0.1852 - val_precision: 0.9875 - val_recall: 0.9611
# Epoch 25/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9932 - loss: 0.0263 - precision: 0.9972 - recall: 0.9885
# Epoch 25: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9932 - loss: 0.0263 - precision: 0.9972 - recall: 0.9885 - val_accuracy: 0.9747 - val_loss: 0.1556 - val_precision: 0.9843 - val_recall: 0.9624
# Epoch 26/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9943 - loss: 0.0227 - precision: 0.9980 - recall: 0.9900
# Epoch 26: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9943 - loss: 0.0227 - precision: 0.9980 - recall: 0.9900 - val_accuracy: 0.9745 - val_loss: 0.1717 - val_precision: 0.9822 - val_recall: 0.9641
# Epoch 27/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9940 - loss: 0.0232 - precision: 0.9978 - recall: 0.9895
# Epoch 27: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.9940 - loss: 0.0232 - precision: 0.9978 - recall: 0.9895 - val_accuracy: 0.9749 - val_loss: 0.1823 - val_precision: 0.9849 - val_recall: 0.9622
# Epoch 28/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9938 - loss: 0.0247 - precision: 0.9974 - recall: 0.9896
# Epoch 28: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9938 - loss: 0.0247 - precision: 0.9973 - recall: 0.9896 - val_accuracy: 0.9752 - val_loss: 0.1626 - val_precision: 0.9851 - val_recall: 0.9626
# Epoch 29/30
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9941 - loss: 0.0228 - precision: 0.9978 - recall: 0.9898
# Epoch 29: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9941 - loss: 0.0228 - precision: 0.9978 - recall: 0.9898 - val_accuracy: 0.9772 - val_loss: 0.1742 - val_precision: 0.9905 - val_recall: 0.9614
# Epoch 30/30
# 344/345 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9941 - loss: 0.0231 - precision: 0.9969 - recall: 0.9906
# Epoch 30: val_accuracy did not improve from 0.97859
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9941 - loss: 0.0231 - precision: 0.9969 - recall: 0.9906 - val_accuracy: 0.9761 - val_loss: 0.1893 - val_precision: 0.9871 - val_recall: 0.9626

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
test_metrics = model.evaluate(X, Y, return_dict=True)
# Out:
# 3065/3065 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.9929 - loss: 0.0362 - precision: 0.9974 - recall: 0.9877

# %%
for name, value in test_metrics.items():
    print(f"{name}: {value*100:.4f} %")
# Out:
# accuracy: 99.3188 %
# loss: 3.6126 %
# precision: 99.7470 %
# recall: 98.8198 %

# %%
model.save("CNN-BLSTM_Model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
